# %%
print("hello")
# Out:
# hello

# %%
var x = 0
# Out:
#   Cell In[2], line 1
#     var x = 0
#         ^
# SyntaxError: invalid syntax

# %%
x=0
x++
# Out:
#   Cell In[3], line 2
#     x++
#        ^
# SyntaxError: invalid syntax

# %%
x=0
x=x+1

# %%
print(x)
# Out:
# 1

# %%
x+=1
print(x)
# Out:
# 2
